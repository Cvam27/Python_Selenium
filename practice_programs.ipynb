# %%
name = "shivam 100"

result = ""
for ch in name:
    if ch.isdigit():
        result += ch

print(result)
# Out:
# 100

# %%
name = "shivam acharya"
splitname = name.split(" ")
print(splitname)

for i in splitname:
    print(i[0])
# Out:
# ['shivam', 'acharya']
# s
# a
